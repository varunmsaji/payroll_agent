# %%
import requests

BASE_URL = "http://127.0.0.1:8000/admin"   # change if needed


def test_get(url, params=None):
    print(f"\n➡ GET {url}")
    r = requests.get(url, params=params)
    print("Status:", r.status_code)
    try:
        print("Response:", r.json())
    except:
        print("Response:", r.text)
    print("-" * 50)


# ------------------------------------------------------
# 1️⃣ Total Employees + Active Employees
# ------------------------------------------------------
test_get(f"{BASE_URL}/employees-summary")

# ------------------------------------------------------
# 2️⃣ Today's Attendance Summary
# ------------------------------------------------------
test_get(f"{BASE_URL}/attendance-today")

# ------------------------------------------------------
# 3️⃣ Late / On-time / Absent
# ------------------------------------------------------
test_get(f"{BASE_URL}/late-on-time-absent")

# ------------------------------------------------------
# 4️⃣ Overtime Today
# ------------------------------------------------------
test_get(f"{BASE_URL}/overtime-today")

# ------------------------------------------------------
# 5️⃣ Monthly Payroll Summary
# ------------------------------------------------------
month = 1
year = 2025
test_get(f"{BASE_URL}/payroll-summary/{month}/{year}")

# ------------------------------------------------------
# 6️⃣ Monthly Working Hours
# ------------------------------------------------------
test_get(f"{BASE_URL}/monthly-hours/{month}/{year}")

# ------------------------------------------------------
# 7️⃣ Recent Attendance Events
# ------------------------------------------------------
test_get(f"{BASE_URL}/recent-events")

# ------------------------------------------------------
# 8️⃣ Shift-wise Employee Distribution
# ------------------------------------------------------
test_get(f"{BASE_URL}/shift-distribution")
# Out:
# ➡ GET http://127.0.0.1:8000/admin/employees-summary
# Status: 200
# Response: [10, 10]
# --------------------------------------------------
#
# ➡ GET http://127.0.0.1:8000/admin/attendance-today
# Status: 200
# Response: [10, 0]
# --------------------------------------------------
#
# ➡ GET http://127.0.0.1:8000/admin/late-on-time-absent
# Status: 200
# Response: [3, 7, 0]
# --------------------------------------------------
#
# ➡ GET http://127.0.0.1:8000/admin/overtime-today
# Status: 200
# Response: [107.61]
# --------------------------------------------------
#
# ➡ GET http://127.0.0.1:8000/admin/payroll-summary/1/2025
# Status: 200
# Response: [None, None, 0, None]
# --------------------------------------------------
#
# ➡ GET http://127.0.0.1:8000/admin/monthly-hours/1/2025
# Status: 200
# Response: []
# --------------------------------------------------
#
# ➡ GET http://127.0.0.1:8000/admin/recent-events
# Status: 200
# ...
