# %%
@router.get("/payroll")
def get_payroll_policy():
    policy = PayrollPolicyDB.get_active_policy()
    if not policy:
        raise HTTPException(status_code=404, detail="No active payroll policy found")
        
    return policy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 @router.get("/payroll")
#       2 def get_payroll_policy():
#       3     policy = PayrollPolicyDB.get_active_policy()
#       4     if not policy:
#
# NameError: name 'router' is not defined
